# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data
# 1. Generate a set of 2,000 random latitudes and longitudes
# 2. Retrieve the nearest city
# 3. Perform an API call with the OpenWeatherMap

# %% [markdown]
# ### 1. Generate a set of 2,000 random latitudes and longitudes

# %%
#Import the dependencies
import pandas as pd
import numpy as np

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ### 2. Retrieve the nearest city

# %%
#Get the nearest city using the citipy module
from citipy import citipy

# %%
#Create a list for holding the cities
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #Add it to the cities list only if it is a unique city
    if city not in cities:
        cities.append(city)
        
#Print the city count
len(cities)
# Out:
# 738

# %% [markdown]
# ### 3. Perform an API call with the OpenWeatherMap

# %%
#Import the requests library
import requests

#Import the API key
from config import weather_api_key

#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in the list.
for i, city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
      
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    #Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    #Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description}) 
    
#If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | dingle
# Processing Record 5 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 1 | lagoa
# Processing Record 7 of Set 1 | lorengau
# Processing Record 8 of Set 1 | hvide sande
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | chimbote
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | los llanos de aridane
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | viransehir
# Processing Record 17 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 1 | hasaki
# Processing Record 19 of Set 1 | luang prabang
# Processing Record 20 of Set 1 | sechura
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | bathsheba
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | kayes
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | henties bay
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | vostok
# Processing Record 32 of Set 1 | muravlenko
# Processing Record 33 of Set 1 | marondera
# Processing Record 34 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | talnakh
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | ureki
# Processing Record 39 of Set 1 | half moon bay
# Processing Record 40 of Set 1 | pitimbu
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | saint-augustin
# Processing Record 43 of Set 1 | ponta do sol
# Processing Record 44 of Set 1 | makkaveyevo
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | tarbagatay
# Processing Record 47 of Set 1 | luau
# Processing Record 48 of Set 1 | constitucion
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | kichera
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | amahai
# Processing Record 5 of Set 2 | north bend
# Processing Record 6 of Set 2 | yulara
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | fort nelson
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | kalianget
# Processing Record 11 of Set 2 | hofn
# Processing Record 12 of Set 2 | kibre mengist
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | kushmurun
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | cherskiy
# Processing Record 17 of Set 2 | lazaro cardenas
# Processing Record 18 of Set 2 | kropotkin
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | san carlos de bariloche
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | bajil
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | price
# Processing Record 27 of Set 2 | berbera
# Processing Record 28 of Set 2 | olafsvik
# Processing Record 29 of Set 2 | yuxia
# Processing Record 30 of Set 2 | teknaf
# Processing Record 31 of Set 2 | saint-joseph
# Processing Record 32 of Set 2 | manzhouli
# Processing Record 33 of Set 2 | hamilton
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | sai buri
# Processing Record 36 of Set 2 | burica
# City not found. Skipping...
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | zhaozhou
# Processing Record 39 of Set 2 | sinnamary
# Processing Record 40 of Set 2 | atbasar
# Processing Record 41 of Set 2 | mount gambier
# Processing Record 42 of Set 2 | ancud
# Processing Record 43 of Set 2 | tambacounda
# Processing Record 44 of Set 2 | drymen
# Processing Record 45 of Set 2 | bambous virieux
# Processing Record 46 of Set 2 | sagaing
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | korla
# Processing Record 49 of Set 2 | portland
# Processing Record 50 of Set 2 | nemuro
# Processing Record 1 of Set 3 | hammerfest
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | san nicolas
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | conde
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | santa fe
# Processing Record 8 of Set 3 | figeac
# Processing Record 9 of Set 3 | awjilah
# Processing Record 10 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | copacabana
# Processing Record 13 of Set 3 | skjervoy
# Processing Record 14 of Set 3 | roma
# Processing Record 15 of Set 3 | monte alegre
# Processing Record 16 of Set 3 | wilmington
# Processing Record 17 of Set 3 | camocim
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | saldanha
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | grindavik
# Processing Record 24 of Set 3 | plettenberg bay
# Processing Record 25 of Set 3 | toronto
# Processing Record 26 of Set 3 | nome
# Processing Record 27 of Set 3 | baykit
# Processing Record 28 of Set 3 | tromso
# Processing Record 29 of Set 3 | manor
# Processing Record 30 of Set 3 | marawi
# Processing Record 31 of Set 3 | kearney
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | wynyard
# Processing Record 34 of Set 3 | riyadh
# Processing Record 35 of Set 3 | luderitz
# Processing Record 36 of Set 3 | airai
# Processing Record 37 of Set 3 | albany
# Processing Record 38 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 3 | faanui
# Processing Record 44 of Set 3 | tucuman
# Processing Record 45 of Set 3 | davila
# Processing Record 46 of Set 3 | marzuq
# Processing Record 47 of Set 3 | broome
# Processing Record 48 of Set 3 | mandurah
# Processing Record 49 of Set 3 | meulaboh
# Processing Record 50 of Set 3 | saint-georges
# Processing Record 1 of Set 4 | mazamari
# Processing Record 2 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 4 | asfi
# Processing Record 4 of Set 4 | dalinghe
# City not found. Skipping...
# Processing Record 5 of Set 4 | mnogovershinnyy
# Processing Record 6 of Set 4 | hilo
# Processing Record 7 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 4 | dudinka
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | katsuura
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | santa vitoria do palmar
# Processing Record 15 of Set 4 | berlevag
# Processing Record 16 of Set 4 | jacareacanga
# Processing Record 17 of Set 4 | tura
# Processing Record 18 of Set 4 | pevek
# Processing Record 19 of Set 4 | bereda
# Processing Record 20 of Set 4 | vestmanna
# Processing Record 21 of Set 4 | mayumba
# Processing Record 22 of Set 4 | richards bay
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | marion
# Processing Record 25 of Set 4 | nikolskoye
# Processing Record 26 of Set 4 | tagusao
# Processing Record 27 of Set 4 | shache
# Processing Record 28 of Set 4 | salalah
# Processing Record 29 of Set 4 | san patricio
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | klaksvik
# Processing Record 32 of Set 4 | lafayette
# Processing Record 33 of Set 4 | chuy
# Processing Record 34 of Set 4 | ust-tsilma
# Processing Record 35 of Set 4 | kribi
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | aojiang
# Processing Record 38 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 4 | kloulklubed
# Processing Record 40 of Set 4 | komyshnya
# Processing Record 41 of Set 4 | antalaha
# Processing Record 42 of Set 4 | bundaberg
# Processing Record 43 of Set 4 | suntar
# Processing Record 44 of Set 4 | te karaka
# Processing Record 45 of Set 4 | obihiro
# Processing Record 46 of Set 4 | corner brook
# Processing Record 47 of Set 4 | ostrovnoy
# Processing Record 48 of Set 4 | yatou
# Processing Record 49 of Set 4 | moussoro
# Processing Record 50 of Set 4 | waingapu
# Processing Record 1 of Set 5 | lamas
# Processing Record 2 of Set 5 | barranca
# Processing Record 3 of Set 5 | avera
# Processing Record 4 of Set 5 | akashi
# Processing Record 5 of Set 5 | khandbari
# Processing Record 6 of Set 5 | sakakah
# Processing Record 7 of Set 5 | hobart
# Processing Record 8 of Set 5 | hithadhoo
# Processing Record 9 of Set 5 | vila franca do campo
# Processing Record 10 of Set 5 | maraa
# Processing Record 11 of Set 5 | tuktoyaktuk
# Processing Record 12 of Set 5 | nova granada
# Processing Record 13 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 5 | soyo
# Processing Record 15 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 16 of Set 5 | burnie
# Processing Record 17 of Set 5 | smithers
# Processing Record 18 of Set 5 | corinth
# Processing Record 19 of Set 5 | ca mau
# Processing Record 20 of Set 5 | kalabo
# Processing Record 21 of Set 5 | ketchikan
# Processing Record 22 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 5 | inhambane
# Processing Record 24 of Set 5 | ciro marina
# Processing Record 25 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 5 | abu dhabi
# Processing Record 27 of Set 5 | maxixe
# Processing Record 28 of Set 5 | taraz
# Processing Record 29 of Set 5 | dauriya
# Processing Record 30 of Set 5 | belz
# Processing Record 31 of Set 5 | khorixas
# Processing Record 32 of Set 5 | loreto
# Processing Record 33 of Set 5 | dunedin
# Processing Record 34 of Set 5 | anadyr
# Processing Record 35 of Set 5 | palmer
# Processing Record 36 of Set 5 | melioratorov
# Processing Record 37 of Set 5 | le port
# Processing Record 38 of Set 5 | mikhaylovka
# Processing Record 39 of Set 5 | gizo
# Processing Record 40 of Set 5 | quatre cocos
# Processing Record 41 of Set 5 | awbari
# Processing Record 42 of Set 5 | poum
# Processing Record 43 of Set 5 | sibut
# Processing Record 44 of Set 5 | kieta
# Processing Record 45 of Set 5 | tevaitoa
# Processing Record 46 of Set 5 | beroroha
# Processing Record 47 of Set 5 | axim
# Processing Record 48 of Set 5 | sheboygan
# Processing Record 49 of Set 5 | ngorongoro
# Processing Record 50 of Set 5 | lalganj
# Processing Record 1 of Set 6 | mujiayingzi
# Processing Record 2 of Set 6 | evensk
# Processing Record 3 of Set 6 | ossora
# Processing Record 4 of Set 6 | ust-uda
# Processing Record 5 of Set 6 | noumea
# Processing Record 6 of Set 6 | ocean city
# Processing Record 7 of Set 6 | ardakan
# Processing Record 8 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | cabo san lucas
# Processing Record 10 of Set 6 | palmas bellas
# Processing Record 11 of Set 6 | pucallpa
# Processing Record 12 of Set 6 | aneho
# Processing Record 13 of Set 6 | kadoma
# Processing Record 14 of Set 6 | rio claro
# Processing Record 15 of Set 6 | lata
# Processing Record 16 of Set 6 | kailua
# Processing Record 17 of Set 6 | karratha
# Processing Record 18 of Set 6 | jijiga
# Processing Record 19 of Set 6 | trairi
# Processing Record 20 of Set 6 | victoria
# Processing Record 21 of Set 6 | aklavik
# Processing Record 22 of Set 6 | zhigansk
# Processing Record 23 of Set 6 | krasnoselkup
# Processing Record 24 of Set 6 | urengoy
# Processing Record 25 of Set 6 | tiarei
# Processing Record 26 of Set 6 | channel-port aux basques
# Processing Record 27 of Set 6 | bethel
# Processing Record 28 of Set 6 | guaymas
# Processing Record 29 of Set 6 | muros
# Processing Record 30 of Set 6 | kiunga
# Processing Record 31 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 6 | moron
# Processing Record 33 of Set 6 | tautira
# Processing Record 34 of Set 6 | paamiut
# Processing Record 35 of Set 6 | cururupu
# Processing Record 36 of Set 6 | kodiak
# Processing Record 37 of Set 6 | ondjiva
# Processing Record 38 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 6 | liku
# Processing Record 40 of Set 6 | frontera
# Processing Record 41 of Set 6 | flinders
# Processing Record 42 of Set 6 | beringovskiy
# Processing Record 43 of Set 6 | shatrovo
# Processing Record 44 of Set 6 | sisophon
# Processing Record 45 of Set 6 | teodoro sampaio
# Processing Record 46 of Set 6 | banda aceh
# Processing Record 47 of Set 6 | natal
# Processing Record 48 of Set 6 | chkalovskoye
# Processing Record 49 of Set 6 | vao
# Processing Record 50 of Set 6 | maridi
# Processing Record 1 of Set 7 | georgetown
# Processing Record 2 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 3 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 7 | tual
# Processing Record 5 of Set 7 | kahului
# Processing Record 6 of Set 7 | khatanga
# Processing Record 7 of Set 7 | leningradskiy
# Processing Record 8 of Set 7 | nioro
# Processing Record 9 of Set 7 | novikovo
# Processing Record 10 of Set 7 | humaita
# Processing Record 11 of Set 7 | semey
# Processing Record 12 of Set 7 | mae ramat
# Processing Record 13 of Set 7 | kandrian
# Processing Record 14 of Set 7 | tessalit
# Processing Record 15 of Set 7 | iqaluit
# Processing Record 16 of Set 7 | namibe
# Processing Record 17 of Set 7 | bichena
# Processing Record 18 of Set 7 | ucluelet
# Processing Record 19 of Set 7 | general roca
# Processing Record 20 of Set 7 | ahipara
# Processing Record 21 of Set 7 | almaznyy
# Processing Record 22 of Set 7 | port augusta
# Processing Record 23 of Set 7 | ballina
# Processing Record 24 of Set 7 | vermillion
# Processing Record 25 of Set 7 | robertson
# Processing Record 26 of Set 7 | fukue
# Processing Record 27 of Set 7 | sao felix do xingu
# Processing Record 28 of Set 7 | hay river
# Processing Record 29 of Set 7 | itarema
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | carnarvon
# Processing Record 32 of Set 7 | rafaela
# Processing Record 33 of Set 7 | panna
# Processing Record 34 of Set 7 | camacha
# Processing Record 35 of Set 7 | bengkulu
# Processing Record 36 of Set 7 | ojinaga
# Processing Record 37 of Set 7 | ilulissat
# Processing Record 38 of Set 7 | rio gallegos
# Processing Record 39 of Set 7 | shingu
# Processing Record 40 of Set 7 | alofi
# Processing Record 41 of Set 7 | srandakan
# Processing Record 42 of Set 7 | corn island
# Processing Record 43 of Set 7 | narsaq
# Processing Record 44 of Set 7 | lompoc
# Processing Record 45 of Set 7 | guiyang
# Processing Record 46 of Set 7 | isangel
# Processing Record 47 of Set 7 | solginskiy
# Processing Record 48 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 49 of Set 7 | koslan
# Processing Record 50 of Set 7 | provideniya
# Processing Record 1 of Set 8 | murighiol
# Processing Record 2 of Set 8 | changde
# Processing Record 3 of Set 8 | cockburn town
# Processing Record 4 of Set 8 | alta floresta
# Processing Record 5 of Set 8 | kushima
# Processing Record 6 of Set 8 | codrington
# Processing Record 7 of Set 8 | saint anthony
# Processing Record 8 of Set 8 | mar del plata
# Processing Record 9 of Set 8 | qandala
# Processing Record 10 of Set 8 | thinadhoo
# Processing Record 11 of Set 8 | halifax
# Processing Record 12 of Set 8 | yumen
# Processing Record 13 of Set 8 | walvis bay
# Processing Record 14 of Set 8 | taut
# Processing Record 15 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 8 | bombay
# Processing Record 17 of Set 8 | homer
# Processing Record 18 of Set 8 | kruisfontein
# Processing Record 19 of Set 8 | saint marys
# Processing Record 20 of Set 8 | mega
# Processing Record 21 of Set 8 | bogorodskoye
# Processing Record 22 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 23 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 24 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 8 | spirit river
# Processing Record 26 of Set 8 | kaeo
# Processing Record 27 of Set 8 | siocon
# Processing Record 28 of Set 8 | beyneu
# Processing Record 29 of Set 8 | rawson
# Processing Record 30 of Set 8 | miri
# Processing Record 31 of Set 8 | bousso
# Processing Record 32 of Set 8 | dusti
# Processing Record 33 of Set 8 | college
# Processing Record 34 of Set 8 | vila
# Processing Record 35 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 8 | duzce
# Processing Record 37 of Set 8 | sabang
# Processing Record 38 of Set 8 | sisimiut
# Processing Record 39 of Set 8 | turukhansk
# Processing Record 40 of Set 8 | saint-pierre
# Processing Record 41 of Set 8 | svetlaya
# Processing Record 42 of Set 8 | ciudad real
# Processing Record 43 of Set 8 | comodoro rivadavia
# Processing Record 44 of Set 8 | upernavik
# Processing Record 45 of Set 8 | ugoofaaru
# Processing Record 46 of Set 8 | mount isa
# Processing Record 47 of Set 8 | aldan
# Processing Record 48 of Set 8 | bystryy istok
# Processing Record 49 of Set 8 | terrace
# Processing Record 50 of Set 8 | biloela
# Processing Record 1 of Set 9 | helena
# Processing Record 2 of Set 9 | coalcoman
# City not found. Skipping...
# Processing Record 3 of Set 9 | vila velha
# Processing Record 4 of Set 9 | port blair
# Processing Record 5 of Set 9 | gravdal
# Processing Record 6 of Set 9 | swift current
# Processing Record 7 of Set 9 | neustadt
# Processing Record 8 of Set 9 | barra do garcas
# Processing Record 9 of Set 9 | souillac
# Processing Record 10 of Set 9 | shar
# Processing Record 11 of Set 9 | aksha
# Processing Record 12 of Set 9 | minsk
# Processing Record 13 of Set 9 | kasongo-lunda
# Processing Record 14 of Set 9 | vilcun
# Processing Record 15 of Set 9 | vestmannaeyjar
# Processing Record 16 of Set 9 | tuatapere
# Processing Record 17 of Set 9 | bin qirdan
# Processing Record 18 of Set 9 | dabhol
# Processing Record 19 of Set 9 | soe
# Processing Record 20 of Set 9 | nizwa
# Processing Record 21 of Set 9 | palauig
# Processing Record 22 of Set 9 | batemans bay
# Processing Record 23 of Set 9 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 24 of Set 9 | puerto escondido
# Processing Record 25 of Set 9 | roald
# Processing Record 26 of Set 9 | sorland
# Processing Record 27 of Set 9 | front royal
# Processing Record 28 of Set 9 | kaspiyskiy
# Processing Record 29 of Set 9 | itoman
# Processing Record 30 of Set 9 | pailon
# Processing Record 31 of Set 9 | ceuta
# Processing Record 32 of Set 9 | naze
# Processing Record 33 of Set 9 | sao gabriel
# Processing Record 34 of Set 9 | sao gotardo
# Processing Record 35 of Set 9 | honningsvag
# Processing Record 36 of Set 9 | port macquarie
# Processing Record 37 of Set 9 | savalou
# Processing Record 38 of Set 9 | cootamundra
# Processing Record 39 of Set 9 | viedma
# Processing Record 40 of Set 9 | ust-kuyga
# Processing Record 41 of Set 9 | bani walid
# Processing Record 42 of Set 9 | opuwo
# Processing Record 43 of Set 9 | skegness
# Processing Record 44 of Set 9 | charters towers
# Processing Record 45 of Set 9 | alappuzha
# Processing Record 46 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 47 of Set 9 | torbat-e jam
# Processing Record 48 of Set 9 | dong hoi
# Processing Record 49 of Set 9 | tigil
# Processing Record 50 of Set 9 | chokurdakh
# Processing Record 1 of Set 10 | pangnirtung
# Processing Record 2 of Set 10 | russell
# Processing Record 3 of Set 10 | daitari
# Processing Record 4 of Set 10 | wajir
# Processing Record 5 of Set 10 | pochutla
# Processing Record 6 of Set 10 | otradnoye
# Processing Record 7 of Set 10 | asau
# Processing Record 8 of Set 10 | qasigiannguit
# Processing Record 9 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 10 | bud
# Processing Record 11 of Set 10 | stykkisholmur
# Processing Record 12 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 13 of Set 10 | guerrero negro
# Processing Record 14 of Set 10 | andenes
# Processing Record 15 of Set 10 | katiola
# Processing Record 16 of Set 10 | verkhnevilyuysk
# Processing Record 17 of Set 10 | puerto carreno
# Processing Record 18 of Set 10 | bambanglipuro
# Processing Record 19 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 10 | sarab
# Processing Record 21 of Set 10 | zabol
# Processing Record 22 of Set 10 | mareeba
# Processing Record 23 of Set 10 | kedrovyy
# Processing Record 24 of Set 10 | ahumada
# City not found. Skipping...
# Processing Record 25 of Set 10 | ryotsu
# Processing Record 26 of Set 10 | uyar
# Processing Record 27 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 29 of Set 10 | iskateley
# Processing Record 30 of Set 10 | gold coast
# Processing Record 31 of Set 10 | kajaani
# Processing Record 32 of Set 10 | thibodaux
# Processing Record 33 of Set 10 | mehamn
# Processing Record 34 of Set 10 | daru
# Processing Record 35 of Set 10 | kupang
# Processing Record 36 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 10 | ambulu
# Processing Record 39 of Set 10 | mizdah
# Processing Record 40 of Set 10 | kirakira
# Processing Record 41 of Set 10 | san vicente
# Processing Record 42 of Set 10 | kavaratti
# Processing Record 43 of Set 10 | paragominas
# Processing Record 44 of Set 10 | waipawa
# Processing Record 45 of Set 10 | santa maria
# Processing Record 46 of Set 10 | graaff-reinet
# Processing Record 47 of Set 10 | nara
# Processing Record 48 of Set 10 | ishigaki
# Processing Record 49 of Set 10 | eyl
# Processing Record 50 of Set 10 | tshikapa
# Processing Record 1 of Set 11 | camapua
# Processing Record 2 of Set 11 | tazovskiy
# Processing Record 3 of Set 11 | nuuk
# Processing Record 4 of Set 11 | huaihua
# Processing Record 5 of Set 11 | ewa beach
# Processing Record 6 of Set 11 | te anau
# Processing Record 7 of Set 11 | kerrobert
# Processing Record 8 of Set 11 | wawa
# Processing Record 9 of Set 11 | kudat
# Processing Record 10 of Set 11 | berdigestyakh
# Processing Record 11 of Set 11 | port hardy
# Processing Record 12 of Set 11 | geilo
# Processing Record 13 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 14 of Set 11 | odweyne
# Processing Record 15 of Set 11 | grenfell
# Processing Record 16 of Set 11 | san quintin
# Processing Record 17 of Set 11 | yar-sale
# Processing Record 18 of Set 11 | lashio
# Processing Record 19 of Set 11 | maryville
# Processing Record 20 of Set 11 | belmonte
# Processing Record 21 of Set 11 | alice springs
# Processing Record 22 of Set 11 | tianpeng
# Processing Record 23 of Set 11 | laguna
# Processing Record 24 of Set 11 | ust-maya
# Processing Record 25 of Set 11 | lecco
# Processing Record 26 of Set 11 | meru
# Processing Record 27 of Set 11 | jega
# Processing Record 28 of Set 11 | dolores
# Processing Record 29 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 30 of Set 11 | komsomolskiy
# Processing Record 31 of Set 11 | sioux lookout
# Processing Record 32 of Set 11 | cap malheureux
# Processing Record 33 of Set 11 | vangaindrano
# Processing Record 34 of Set 11 | flin flon
# Processing Record 35 of Set 11 | sindor
# Processing Record 36 of Set 11 | aracati
# Processing Record 37 of Set 11 | lexington
# Processing Record 38 of Set 11 | belen
# Processing Record 39 of Set 11 | catalao
# Processing Record 40 of Set 11 | antofagasta
# Processing Record 41 of Set 11 | shimoda
# Processing Record 42 of Set 11 | pundaguitan
# Processing Record 43 of Set 11 | jaciara
# Processing Record 44 of Set 11 | sinegorskiy
# Processing Record 45 of Set 11 | mandalgovi
# Processing Record 46 of Set 11 | huancayo
# Processing Record 47 of Set 11 | bestobe
# Processing Record 48 of Set 11 | bontang
# Processing Record 49 of Set 11 | ahuimanu
# Processing Record 50 of Set 11 | olga
# Processing Record 1 of Set 12 | kendari
# Processing Record 2 of Set 12 | coahuayana
# Processing Record 3 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 12 | medea
# Processing Record 5 of Set 12 | el vigia
# Processing Record 6 of Set 12 | lazi
# Processing Record 7 of Set 12 | gazimurskiy zavod
# Processing Record 8 of Set 12 | susanville
# Processing Record 9 of Set 12 | nantucket
# Processing Record 10 of Set 12 | panjakent
# Processing Record 11 of Set 12 | kavieng
# Processing Record 12 of Set 12 | bigaan
# Processing Record 13 of Set 12 | jackson
# Processing Record 14 of Set 12 | tocopilla
# Processing Record 15 of Set 12 | coquimbo
# Processing Record 16 of Set 12 | simao
# Processing Record 17 of Set 12 | villarrica
# Processing Record 18 of Set 12 | sokolo
# Processing Record 19 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 12 | moose factory
# Processing Record 21 of Set 12 | kamina
# Processing Record 22 of Set 12 | poretskoye
# Processing Record 23 of Set 12 | laguna de perlas
# Processing Record 24 of Set 12 | makung
# City not found. Skipping...
# Processing Record 25 of Set 12 | nishihara
# Processing Record 26 of Set 12 | carauari
# Processing Record 27 of Set 12 | barra patuca
# Processing Record 28 of Set 12 | sayyan
# Processing Record 29 of Set 12 | santa rosa
# Processing Record 30 of Set 12 | puerto narino
# Processing Record 31 of Set 12 | portree
# Processing Record 32 of Set 12 | coos bay
# Processing Record 33 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 12 | kysyl-syr
# Processing Record 36 of Set 12 | dzerzhinskoye
# Processing Record 37 of Set 12 | tsentralnyy
# City not found. Skipping...
# Processing Record 38 of Set 12 | acapulco
# Processing Record 39 of Set 12 | dandong
# Processing Record 40 of Set 12 | samarai
# Processing Record 41 of Set 12 | chipinge
# Processing Record 42 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 12 | muroto
# Processing Record 44 of Set 12 | sarangani
# Processing Record 45 of Set 12 | hami
# Processing Record 46 of Set 12 | bilma
# Processing Record 47 of Set 12 | salinas
# Processing Record 48 of Set 12 | haimen
# Processing Record 49 of Set 12 | westport
# Processing Record 50 of Set 12 | kuopio
# Processing Record 1 of Set 13 | sao jose da coroa grande
# Processing Record 2 of Set 13 | moerai
# Processing Record 3 of Set 13 | conceicao do araguaia
# Processing Record 4 of Set 13 | surgut
# Processing Record 5 of Set 13 | vardo
# Processing Record 6 of Set 13 | boralday
# Processing Record 7 of Set 13 | maceio
# Processing Record 8 of Set 13 | abashiri
# Processing Record 9 of Set 13 | cayenne
# Processing Record 10 of Set 13 | dalbandin
# Processing Record 11 of Set 13 | preobrazheniye
# Processing Record 12 of Set 13 | gazojak
# Processing Record 13 of Set 13 | lavrentiya
# Processing Record 14 of Set 13 | panjab
# Processing Record 15 of Set 13 | lokoja
# Processing Record 16 of Set 13 | caravelas
# Processing Record 17 of Set 13 | the valley
# Processing Record 18 of Set 13 | camopi
# Processing Record 19 of Set 13 | fortuna
# Processing Record 20 of Set 13 | oktyabrskoye
# Processing Record 21 of Set 13 | banikoara
# Processing Record 22 of Set 13 | carutapera
# Processing Record 23 of Set 13 | megion
# Processing Record 24 of Set 13 | batagay-alyta
# Processing Record 25 of Set 13 | margate
# Processing Record 26 of Set 13 | nabire
# Processing Record 27 of Set 13 | harper
# Processing Record 28 of Set 13 | izumo
# Processing Record 29 of Set 13 | champerico
# Processing Record 30 of Set 13 | bumba
# Processing Record 31 of Set 13 | hohhot
# Processing Record 32 of Set 13 | babina
# Processing Record 33 of Set 13 | nieves
# Processing Record 34 of Set 13 | haines junction
# Processing Record 35 of Set 13 | goundam
# Processing Record 36 of Set 13 | vanimo
# Processing Record 37 of Set 13 | aranos
# Processing Record 38 of Set 13 | brae
# Processing Record 39 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 40 of Set 13 | biak
# Processing Record 41 of Set 13 | visby
# Processing Record 42 of Set 13 | havoysund
# Processing Record 43 of Set 13 | uruzgan
# Processing Record 44 of Set 13 | aden
# Processing Record 45 of Set 13 | gobabis
# Processing Record 46 of Set 13 | keita
# Processing Record 47 of Set 13 | buala
# Processing Record 48 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 13 | sao joao da barra
# Processing Record 50 of Set 13 | phonhong
# Processing Record 1 of Set 14 | takayama
# Processing Record 2 of Set 14 | sompeta
# Processing Record 3 of Set 14 | tigzirt
# Processing Record 4 of Set 14 | honiara
# Processing Record 5 of Set 14 | mogadishu
# Processing Record 6 of Set 14 | anaco
# Processing Record 7 of Set 14 | humberto de campos
# Processing Record 8 of Set 14 | srednekolymsk
# Processing Record 9 of Set 14 | bonthe
# Processing Record 10 of Set 14 | agadez
# Processing Record 11 of Set 14 | bridlington
# Processing Record 12 of Set 14 | bay roberts
# Processing Record 13 of Set 14 | torremolinos
# Processing Record 14 of Set 14 | husavik
# Processing Record 15 of Set 14 | chilliwack
# Processing Record 16 of Set 14 | emerald
# Processing Record 17 of Set 14 | fairbanks
# Processing Record 18 of Set 14 | grand-lahou
# Processing Record 19 of Set 14 | cheney
# Processing Record 20 of Set 14 | dali
# Processing Record 21 of Set 14 | baringo
# Processing Record 22 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 14 | mahon
# Processing Record 24 of Set 14 | vaitape
# Processing Record 25 of Set 14 | dharchula
# Processing Record 26 of Set 14 | havelock
# Processing Record 27 of Set 14 | obera
# Processing Record 28 of Set 14 | millau
# Processing Record 29 of Set 14 | dubuque
# Processing Record 30 of Set 14 | paramonga
# Processing Record 31 of Set 14 | mount pleasant
# Processing Record 32 of Set 14 | johnstown
# Processing Record 33 of Set 14 | beloha
# Processing Record 34 of Set 14 | piacabucu
# Processing Record 35 of Set 14 | marienburg
# Processing Record 36 of Set 14 | alice town
# Processing Record 37 of Set 14 | port hedland
# Processing Record 38 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 14 | ekibastuz
# Processing Record 40 of Set 14 | kempen
# Processing Record 41 of Set 14 | glens falls
# Processing Record 42 of Set 14 | mao
# Processing Record 43 of Set 14 | weyburn
# Processing Record 44 of Set 14 | pindamonhangaba
# Processing Record 45 of Set 14 | acarau
# Processing Record 46 of Set 14 | lasa
# Processing Record 47 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 14 | okhotsk
# Processing Record 49 of Set 14 | diffa
# Processing Record 50 of Set 14 | broken hill
# Processing Record 1 of Set 15 | kyshtovka
# Processing Record 2 of Set 15 | bella union
# Processing Record 3 of Set 15 | auray
# Processing Record 4 of Set 15 | jaisalmer
# Processing Record 5 of Set 15 | vitim
# Processing Record 6 of Set 15 | katherine
# Processing Record 7 of Set 15 | teya
# Processing Record 8 of Set 15 | zinder
# Processing Record 9 of Set 15 | sur
# Processing Record 10 of Set 15 | lumding
# Processing Record 11 of Set 15 | druzhba
# Processing Record 12 of Set 15 | nuwara eliya
# Processing Record 13 of Set 15 | bulawayo
# Processing Record 14 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 15 | buraydah
# Processing Record 16 of Set 15 | goure
# Processing Record 17 of Set 15 | gerash
# Processing Record 18 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 19 of Set 15 | arroyo
# Processing Record 20 of Set 15 | constantine
# Processing Record 21 of Set 15 | necochea
# Processing Record 22 of Set 15 | chapais
# Processing Record 23 of Set 15 | palpa
# Processing Record 24 of Set 15 | nileshwar
# Processing Record 25 of Set 15 | hervey bay
# Processing Record 26 of Set 15 | paita
# Processing Record 27 of Set 15 | lahij
# Processing Record 28 of Set 15 | sokoni
# Processing Record 29 of Set 15 | lufilufi
# Processing Record 30 of Set 15 | kontagora
# Processing Record 31 of Set 15 | trincomalee
# Processing Record 32 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 15 | kidal
# Processing Record 34 of Set 15 | keuruu
# Processing Record 35 of Set 15 | uige
# Processing Record 36 of Set 15 | bandarbeyla
# Processing Record 37 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 15 | sibu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     76.86        57          75
# 1      East London      ZA -33.0153   27.9116     59.94        94          75
# 2           Atuona      PF  -9.8000 -139.0333     78.46        78          29
# 3           Dingle      PH  10.9995  122.6711     76.03        92          62
# 4            Lagoa      PT  39.0500  -27.9833     58.80        79          79
# 5         Lorengau      PG  -2.0226  147.2712     81.63        78          37
# 6      Hvide Sande      DK  56.0045    8.1294     48.09        74         100
# 7     Punta Arenas      CL -53.1500  -70.9167     50.11        93          75
# 8         Chimbote      PE  -9.0853  -78.5783     71.15        73          33
# 9      Port Alfred      ZA -33.5906   26.8910     61.18        83          99
#
#    Wind Speed Current Description
# 0       24.16       broken clouds
# 1       12.66       broken clouds
# 2       15.03          light rain
# 3        1.97       broken clouds
# 4       20.33       broken clouds
# 5        5.91    scattered clouds
# 6        9.84     overcast clouds
# 7       11.50       broken clouds
# 8       10.80    scattered clouds
# 9        3.00     overcast clouds

# %%
#Format the Lat and Lng columns in the DataFrame.
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df.head(10)
# Out:
#               City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR  -22.97   -42.03     76.86        57          75
# 1      East London      ZA  -33.02    27.91     59.94        94          75
# 2           Atuona      PF   -9.80  -139.03     78.46        78          29
# 3           Dingle      PH   11.00   122.67     76.03        92          62
# 4            Lagoa      PT   39.05   -27.98     58.80        79          79
# 5         Lorengau      PG   -2.02   147.27     81.63        78          37
# 6      Hvide Sande      DK   56.00     8.13     48.09        74         100
# 7     Punta Arenas      CL  -53.15   -70.92     50.11        93          75
# 8         Chimbote      PE   -9.09   -78.58     71.15        73          33
# 9      Port Alfred      ZA  -33.59    26.89     61.18        83          99
#
#    Wind Speed Current Description
# 0       24.16       broken clouds
# 1       12.66       broken clouds
# 2       15.03          light rain
# 3        1.97       broken clouds
# 4       20.33       broken clouds
# 5        5.91    scattered clouds
# 6        9.84     overcast clouds
# 7       11.50       broken clouds
# 8       10.80    scattered clouds
# 9        3.00     overcast clouds

# %%
#Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

#Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
